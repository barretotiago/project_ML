# %% [markdown]
# # **1 - Instalar e carregar bibliotecas**

# %%
# !pip install wandb

# %%
import wandb
import pandas as pd

# %% [markdown]
# 1.1 - Criar os artefatos primários (https://archive.ics.uci.edu/ml/datasets/Car+Evaluation)

# %%
#colunas utilizadas

colums = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'assessment']

#importando dataset

income = pd.read_csv ("https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data", header = None, names = colums)

income.head()
# Out:
#   buying  maint doors persons lug_boot safety assessment
# 0  vhigh  vhigh     2       2    small    low      unacc
# 1  vhigh  vhigh     2       2    small    med      unacc
# 2  vhigh  vhigh     2       2    small   high      unacc
# 3  vhigh  vhigh     2       2      med    low      unacc
# 4  vhigh  vhigh     2       2      med    med      unacc

# %%
income.to_csv("raw_data.csv",index=False)

# %%
# Login to Weights & Biases
# !wandb login --relogin
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# Send the raw_data.csv to the Wandb storing it as an artifact
# !wandb artifact put \
      --name decision_tree/raw_data.csv \
      --type raw_data \
      --description "The raw data from cars database" raw_data.csv
# Out:
# wandb: Uploading file raw_data.csv to: "tiagobarreto/decision_tree/raw_data.csv:latest" (raw_data)
# wandb: Currently logged in as: tiagobarreto. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.16
# wandb: Run data is saved locally in /content/wandb/run-20220522_143300-169jtv04
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run decent-salad-5
# wandb: ⭐️ View project at https://wandb.ai/tiagobarreto/decision_tree
# wandb: 🚀 View run at https://wandb.ai/tiagobarreto/decision_tree/runs/169jtv04
# Artifact uploaded, use this artifact in a run by adding:
#
#     artifact = run.use_artifact("tiagobarreto/decision_tree/raw_data.csv:latest")
#
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Synced decent-salad-5: https://wandb.ai/tiagobarreto/decision_tree/runs/169jtv04
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# ...
